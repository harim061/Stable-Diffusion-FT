# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "nitrosocke/classic-anim-diffusion"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# unet/diffusion_pytorch_model.safetensors not found
# Loading pipeline components...: 100%|██████████| 7/7 [00:02<00:00,  2.73it/s]
# 100%|██████████| 50/50 [00:02<00:00, 16.96it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "classic disney style magical princess with golden hair and castle"
image = pipe(prompt).images[0]
image
# Out:
# 100%|██████████| 50/50 [00:02<00:00, 16.69it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
